# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %% [markdown]
# ## __UniCode__
#
# __Hens Zimmerman__
#
# [henszimmerman@gmail.com](mailto:henszimmerman@gmail.com)
#
# In deze reeks artikelen leer je programmeren met de programmeertaal Python. Python is een gratis open source programmeertaal, die je kunt gebruiken op bijna alle soorten computers. Als je nog maar net begint met programmeren, en geen idee hebt waar je moet beginnen, begin dan met __Anaconda Python__ 3.6 of hoger. De download vind je hier: https://www.anaconda.com/. Natuurlijk gaat onze voorkeur uit naar astronomische berekeningen, maar soms maken we een uitstapje naar iets anders. Zo gaan we in deze aflevering bezig met datum en tijd én afbeeldingen maken met [matplotlib](https://matplotlib.org). Datum en tijd hebben we al wel eens vaker bekeken. Matplotlib is een populaire module voor Python waar je data mee kunt weergeven. Maar niet alleen grafieken (al is matplotlib daar wel _uiterst_ geschikt voor), maar ook computergegenereerde afbeeldingen of tekst.
#
# Verder gaan we kijken naar [Jupyter](http://jupyter.org) notebooks. Dat zijn interactieve webpagina's, die Python code kunnen uitvoeren. Je _hoeft_ natuurlijk geen Jupyter notebooks te gebruiken om te leren programmeren, maar ze maken, zoals je zult zien, je leven wel een stuk gemakkelijker! En ook leuker. Alle nog volgende afleveringen van onze serie UniCode kun je vanaf nu ook als Jupyter notebook terugvinden op het interweb. Dat betekent dat je niet alles hoeft over te typen én dat je kunt experimenteren met de Python code. Super handig dus. Als je meer over Jupyter wilt weten kun je [hier](https://www.datacamp.com/community/tutorials/tutorial-jupyter-notebook) kijken.
#
# __Voer de code in Jupyter notebooks wel in volgorde van boven naar beneden uit, anders bestaat er een kans dat je foutmeldingen krijgt.__
#
# De link naar de [UniCode Jupyter notebooks](http://bit.ly/JWGUniCode) is gemakkelijk te onthouden: [bit.ly/JWGUniCode](http://bit.ly/JWGUniCode).
#
# Nog een kleinigheid: als je zelf met Jupyter notebooks bezig wilt, dan is het handig om wat [markdown](https://www.markdownguide.org) te leren. Dat is een handig taaltje, dat je overal op het internet tegenkomt om documenten mee op te maken. Het is eenvoudiger te leren dan HTML, simpelweg omdat het veel minder commando's kent.

# %% [markdown]
# ## Jupyter notebooks
#
# ### Wat heb je nodig?
#
# Je kunt zelf Jupyter installeren, maar het is veel gemakkelijker om Anaconda Python te installeren. De download vind je hier: https://www.anaconda.com/. Anaconda Python is er voor Linux, OSX en Windows. In de afbeelding zie je hoe het er bijvoorbeeld in het Windows 10 start menu uitziet.
#
# <img src="http://henszimmerman.audio/universum/1.png" align="left" alt="" style="float: left; margin: 0px 15px 15px 15px;" />

# %% [markdown]
# In de Anaconda installatie van je Apple OSX computer ziet het er anders uit. Daar start je de __Anaconda Navigator__ en kiest dan __Jupyter notebook__. Vanaf dan ziet Jupyter er verrassend hetzelfde uit op alle verschillende operating systems. Good job!
#
# <img src="http://henszimmerman.audio/universum/7.png" align="left" alt="" style="float: left; margin: 0px 15px 15px 15px;" />

# %% [markdown]
# ### Opstarten
#
# Nadat Jupyter opgestart is (dat duurt even...), opent de default browser met een pagina die de inhoud van je computer laat zien.
#
# <img src="http://henszimmerman.audio/universum/2.png" align="left" alt="" style="float: none; margin: 0px 15px 15px 15px;" />
#
# Bij jou ziet het er beslist anders uit. Allereerst omdat ik dit typ op 4 juli 2018 en jij dit op een latere datum leest. Verder is [Google Chrome](https://www.google.com/chrome/) mijn default browser, en dat is bij jou misschien anders. En verder heb jij heel andere mappen en documenten op je computer staan.
#
# Een paar dingen vallen hier al op:
#
# * Het adres in de browser. Bij mij is dat http://localhost:8888/tree. Localhost wil zeggen dat je naar je eigen computer zit te kijken. Dit is dus geen pagina op het internet. Maar voor je webbrowser is het allemaal om het even.
#
# * Je kunt op mapjes (folders) klikken en zo naar een bepaalde plek op jouw computer navigeren. Het is slim om een map aan te maken voor je Jupyter notebooks, waarvan jij weet waar die staat.
#
# * Met __Name__ en __Last modified__ kun je de lijst sorteren. Da's wel zo makkelijk.
#
# * Rechtsboven zie je __Upload__ en __New__. Daarmee kun je Jupyter notebooks uploaden en maken.
#
# * Er zijn 3 tabs met de titels __Files__, __Running__ en __Clusters__. Die zou ik voor nu even vergeten. Je kunt altijd dieper in de Jupyter notebooks duiken door [deze link](https://www.datacamp.com/community/tutorials/tutorial-jupyter-notebook) te volgen of te googelen naar Jupyter tutorials.

# %% [markdown]
# ### Een Jupyter notebook maken
#
# <img src="http://henszimmerman.audio/universum/3.png" align="left" alt="" style="float: left; margin: 0px 15px 15px 15px;" />
#
# Als je op __New__ klikt, verschijnt er een popup venster. In mijn geval kan ik een __Python 3__ of een __R__ document maken.  Jij hebt misschien andere opties. Uiteraard gaan we voor een __Python 3__ notebook, maar je bent misschien ook benieuwd wat een __R__ document is. [R](https://www.r-project.org) is een open source statistische programmeertaal. Zowel __Python__ als __R__ zijn op dit moment uiterst populair, zeker ook in de astronomie. Maar neem niet gelijk teveel hooi op je vork!
#
# Voor nu maken we een __Python 3__ Jupyter notebook. Leuk aan Anaconda Python is, dat het gelijk al een heleboel mooie modules voor je installeert. Je kunt in je notebook onder andere gebruik maken van [NumPy](http://www.numpy.org), [SciPy](https://www.scipy.org) en [Matplotlib](https://matplotlib.org). Meestal zal Anaconda ook vette modules als [astropy](http://www.astropy.org), [cudatoolkit](https://en.wikipedia.org/wiki/CUDA), [django](https://www.djangoproject.com), [nodejs](https://nodejs.org/en/) en teveel om op te noemen installeren. Verder kan een Jupyter notebook alle modules die je in jouw __Python 3__ hebt geïnstalleerd gebruiken. Hoe cool is dat?
#
# Een Jupyter notebook bestaat uit losse cellen. Voor het gemak kunnen we zeggen dat een cel óf tekst of Python code bevat. Eigenlijk kun je dus een webpagina maken die tekst en uitleg geeft én uitvoerbare programmacode bevat. Zowel de tekst als de programmacode kun je bewerken en het resultaat daarvan direct bekijken. Een cel bewerk je door er op te dubbelklikken.
#
# De cellen met tekst erin bevatten zoals gezegd [markdown](https://nl.wikipedia.org/wiki/Markdown). __Markdown__ is een lichtgewicht opmaaktaal op basis van platte tekst die zodanig ontworpen is dat het gemakkelijk valt te converteren naar een webpagina. Tekst in deze opmaaktaal is gemakkelijk te maken met een simpele teksteditor zoals notepad of TextEdit, maar in het geval van Jupyter notebooks kun je gewoon in je browser typen. Het ontwerpdoel van __markdown__ is leesbaarheid. Teksten geschreven met behulp van __markdown__ worden geacht al leesbaar te zijn voordat opmaak is toegepast op de tekst.
#
# De cellen met Python code erin bevatten gewoon Python instructies. Maar... als je zo'n Python cel uitvoert, dan wordt de output daarvan eronder weergegeven.

# %% [markdown]
# ### Een nieuwe cel maken
#
# <img src="http://henszimmerman.audio/universum/5.png" align="left" alt="" style="float: none; margin: 0px 0px 15px 15px;" />
#
# Bovenin je nieuwe Jupyter notebook zie je een menubalk. Het eerste icoontje gebruik je om je wijzigingen op te slaan. Doe dat vaak, want het is sonde als je alles weer opnieuw moet typen.
#
# Het plusje daarnaast gebruik je om een nieuwe cel aan te maken. Als eerste moet je nu bedenken of het een __markdown__ of een __code__ cel wordt. In de afbeelding zie je hoe dat er bij mij uitziet. Probeer maar eens een cel aan te maken met wat __markdown__ tekst erin. Om het resultaat van je werk te zien klik je op het pijltje naar rechts met het streepje, ook in het menu. Dit geldt voor zowel markdown als code cellen. Het vierkantje ernaast is ervoor om Python weer te stoppen. Vooral handig als je iets hebt geprogrammeerd wat niet meer stopt.
#
# Met de andere knoppen in het menu kun je zelf experimenteren. Ze zijn vooral handig om de volgorde van cellen te veranderen.
#
# Rechtsboven zie je misschien nog een knop met __Edit Metadata__. [Metadata](https://nl.wikipedia.org/wiki/Metadata) zijn gegevens die gegevens beschrijven. Voor nu kun je dat even links laten liggen. Als je er mee wilt experimenteren, weet dan dat Jupyter cel metadata in het [JSON](https://nl.wikipedia.org/wiki/JSON) formaat wordt opgeslagen.
#
# ### Python code!
#
# Ja, eindelijk gaan we weer programmeren! Maak in je Jupyter notebook een code cel aan, met de code hieronder. Verander gerust de tekst van de variabele __MijnNaam__. Om je code uit te voeren klik je bovenin het menu dus op het pijltje naar rechts met het streepje. Met enige mazzel zie je dan onder je code cel de output verschijnen.
#
# <img src="http://henszimmerman.audio/universum/6.png" align="left" alt="" style="float: left; margin: 0px 15px 15px 15px;" />
# __Belangrijke tip!!__ Met de __tab__ toets van je toetsenbord kun je in Jupyter notebooks heel snel werken, zoals je misschien ook al wel gewend bent in iPython. Als je het begin van code typt, krijg je een uitklap menu met mogelijke opties. Dat scheelt bergen typen en verkleint de kans op fouten! In het plaatje zie je hoe ik __import ma__ heb getypt en vervolgens op __tab__ heb gedrukt.

# %%
# Even oefenen! In een Jupyter notebook kun je gewoon typen.
# Verander hieronder de regel code met jouw naam en klik op "Run Cell" (pijltje met streepje bovenaan).

MijnNaam = "Sophie van de Toekomst"

for idx in range(0, len(MijnNaam) + 1):
    print(MijnNaam[:idx])

# %%
# Ook leuk is om te zien welke modules er eigenlijk zijn geinstalleerd in jouw Python.
# Daar zijn verschillende methodes voor, zoals ook bijvoorbeeld:
# help("modules")
# ...maar de volgende methode is erg overzichtelijk.

import sys as s

# modules.keys() is een zogenaamde "dictionary" (een woordenboek) van de namen
# van alle modules. Die kun je sorteren met de sorted() functie van Python.
# De for-loop wandelt er dan een voor een doorheen en print elke module.

for idx in sorted(s.modules.keys()):
    print(idx)

# En je zult zien dat de Jupyter notebooks een scrollbar in een cel met teveel tekst zetten,
# zodat je notebook niet idioot lang wordt. Handig toch?

# %% [markdown]
# ## Belangrijk! Belangrijk! Belangrijk!
#
# <img src="http://henszimmerman.audio/universum/8.png" align="left" alt="" style="float: none; margin: 0px 15px 15px 15px;" />
#
# Als je via http://bit.ly/JWGUniCode naar een Jupyter notebook kijkt, dan kun je wijzigingen aanbrengen en zelfs bewaren. Tenminste... dat lijkt zo. Als je je browsersessie afsluit, zijn al jouw wijzigingen weer verdwenen. Als je de UniCode Jupyter notebooks wilt wijzigen, bewaar dan je eigen copie ergens op jouw computer. In de afbeelding zie je hoe je een UniCode notebook als Jupyter notebook kunt downloaden. Vervolgens open je __die copie__ in Jupyter. Je kunt direct zien of je voor janine-met-de-korte-achternaam zit te editen of op je eigen computer werkt:
#
# * Staat er in de adresbar van je browser het woord __localhost__, dan zit je waarschijnlijk goed. Dan kijk je naar een Jupyter notebook op jouw computer.
#
# * Staat er daarentegen __mybinder.org__ in de adresbar van je browser, dan zit je de internetversie te editen. Dat werkt allemaal wel, maar houd er rekening mee dat je wijzigingen niet bewaard worden. Wat is [mybinder.org](https://mybinder.org)? Nou, dat is een plaats om Jupyter notebooks met de wereld te delen. MyBinder copieert de UniCode Jupyter notebooks van [mijn GitHub account](https://github.com/hz37/UniCode-JWG), die je, als je bekend bent met [GitHub](https://github.com/) natuurlijk ook kunt gebruiken om de UniCode Jupyter notebooks locaal op je computer te krijgen.

# %% [markdown]
# ## Voor nu even genoeg over Jupyter notebooks
#
# We gaan, zoals beloofd, wat datum en tijd berekeningen doen. Je kunt deze gewoon in elke Python uitvoeren, maar het is natuurlijk wel leuk en nuttig om het in Jupyter te proberen.

# %% [markdown]
# ## Datum en Tijd
#
# Heel vaak tijdens het programmeren hebben we te maken met datum en tijd. Zeker in de sterrenkunde, waar veel interessante gebeurtenissen precies op een bepaald moment plaatsvinden.
#
# __NB:__ Als je dit als Jupyter notebook uitvoert, zie je misschien niet de juiste tijd. Dat heeft er mee te maken dat de Jupyter notebooks worden uitgevoerd op de servers van MyBinder en niet op jouw computer thuis. Zie hierboven hoe je een locale copie van een UniCode Jupyter notebook kunt krijgen.

# %%
# Python heeft een module time, die we goed kunnen gebruiken voor datum-tijd-berekeningen.

import time 

# De functie localtime() geeft ons een tuple terug, maar dat leest niet zo prettig.

print(time.localtime())

# Maar we kunnen uiteraard de verschillende velden van time.localtime() zelf gebruiken
# in onze Python code.

t = time.localtime()

print("Het is " + str(t.tm_mday) + "-" + str(t.tm_mon) + "-" + str(t.tm_year))

# En precies hetzelfde resultaat krijg je zo. Misschien iets netter?

print("Het is %d-%d-%d" % (t.tm_mday, t.tm_mon, t.tm_year))

# Of wat dacht je hier van?

print("Het is {}-{}-{}".format(t.tm_mday, t.tm_mon, t.tm_year))

# Kortom... vele wegen naar Rome!

# %%
# Met de functie asctime() hebben we snel een leesbare datum en tijd.
# Alleen hebben we minder controle over hoe het er op het scherm uitziet.

print(time.asctime())

# %%
# Maar met strftime() hebben we totale controle over hoe we de datum en tijd weergeven.
# Wat je allemaal kunt weergeven vind je hier: https://docs.python.org/2/library/time.html#time.strftime
# Een paar voorbeelden:

nu = time.localtime()

print(time.strftime("Het is %H:%M uur op %d %B %Y.", nu))

print(time.strftime("Exacte tijd: %H:%M:%S", nu))

print(time.strftime("%X %x", nu))

print(time.strftime("It's %A %b %d, %Y - %I:%M %p", nu))

# Probeer het zelf ook eens! Hier zijn de parameters die strftime begrijpt.

# %a	Afgekorte dag van de week.
# %A	Volledige dag van de week.
# %w	Dag van de week als nummer (zondag is 0).
# %d	Dag met twee cijfers
# %-d	Dag als een cijfer
# %b	Afgekorte naam van de maand.
# %B	Volledige naam van de maand.
# %m	Maand met twee cijfers.
# %-m	Maand als cijfer.
# %y	Jaar als twee cijfers.
# %Y	Jaar met vier cijfers.
# %H	Uur met twee cijfers (24 urige klok).
# %-H	Uur (24 urige klok).
# %I	Uur met twee cijfers (12 urige klok).
# %-I	Uur (12 urige klok).
# %p	AM of PM.
# %M	Minuut als twee cijfers.
# %-M	Minuut.
# %S	Seconde als twee cijfers.
# %-S	Seconde.
# %f	Microseconden.
# %z	UTC offset.
# %Z	Naam van tijdzone.
# %j	Dag van het jaar met drie cijfers.
# %-j	Day van het jaar.
# %U	Weeknummer met twee cijfers.
# %W	Weeknummer.
# %c	Datum en tijd als string.
# %x	Datum als string.
# %X	Tijd als string.
# %%	Een percentage teken.

# %%
# Een kalender is ook geen probleem in Python!
# Als je dit voorbeeld in Jupyter uitvoert, zul je zien dat je
# ook antwoorden kunt invullen die voor input() worden gebruikt.

import calendar

# We blijven geduldig in de while-loop tot we goede input ontvangen
# van de gebruiker. Dat betekent een geldig jaar en een geldige maand.

goedeInput = False

while not goedeInput:
    # Vraag de gebruiker om een jaar en maand.
    
    jaar = input("In welk jaar ben je geboren? ")
    maand = input("En in welke maand ben je geboren [1-12]? ")

    try:
        jaar =  int(jaar)
        maand = int(maand)
        
        # Hier komen we pas aan als jaar en maand getallen zijn!
        # Maar we stellen nog wel wat eisen aan maand en jaar.
        
        goedeInput = (maand >= 1) & (maand <= 12) & (jaar >= 0)
        
    except ValueError:
        # Hier komen we aan als iemand (een grappenmaker) geen getal
        # invult voor jaar of maand. De functie int() hierboven heeft
        # de input van de gebruiker dan niet kunnen vertalen naar een nummer
        # en er treedt een ValueError op.
        
        print("Grappenmaker!")

# Hier zijn we uit de while-loop, dus hebben we een juist jaar en een juiste maand.        
        
print("Hier is een kalender van je geboortemaand:\n")

# In de variabele cal zetten we de geboortekalender.

cal = calendar.month(jaar, maand)

# En die kalender printen we uit.

print(cal)

# %% [markdown]
# ## Even wat tips tussendoor
#
# Als je plezier hebt in het programmeren met Python en sneller wilt leren, dan zijn er op internet allerlei plaatsen te vinden waar je zelf aan de slag kunt. Ter inspiratie zijn hier een paar van de betere sites:
#
# - [HackerRank](https://www.hackerrank.com/): Op deze site kun je allemaal kleine oefeningen doen, waardoor je punten verzamelt en steeds beter wordt. Het kost helemaal niks, en je kunt er op den duur zelfs betaald werk mee vinden!
#
# - [Project Euler](https://projecteuler.net): Deze website is een lange reeks van steeds moeilijker wordende wiskunde- en programmeeruitdagingen. Kost weer helemaal geen cent en je wordt al doende beter en beter.
#
# - [NAND to Tetris](http://www.nand2tetris.org): Dit is geen Python website, maar wel een heel goede manier om te leren hoe computers werken. De website is ook gratis, en je leer eerst NAND geheugen te bouwen, en daarmee bouw je een steeds beter functionerende virtuele computer.
#
# - [Coder Byte](https://coderbyte.com): Deze website heeft ook een betaald gedeelte, maar je kunt gratis Python leren en uitdagingen accepteren.
#
# - [Practice Python](https://www.practicepython.org): Okay, misschien niet de meest gelikte website, maar je vindt er uitdagingen én oplossingen.
#
# - [Code Wars](http://www.codewars.com): Hele mooie site, waar je ook kunt betalen voor nog meer mogelijkheden. Maar genoeg te doen zonder dat je je portemonnee hoeft te trekken!
#
# - [W3 Resource](https://www.w3resource.com/python-exercises/): Tot slot deze site, waar je gratis Python problemen kunt oplossen en ook oplossingen kunt inzien.
#
# Loop je vast tijdens het programmeren? [Google](https://www.google.com) is je vriendin! Je kunt ook rechtstreeks zoeken in [Stack Overflow](https://stackoverflow.com), waar werkelijk alles al een keer gevraagd is op het gebied van Python problemen en wat dies meer zij.

# %% [markdown]
# ## Tijd en Matplotlib
#
# Wat we nu gaan doen is een simpele X/Y grafiek tekenen van __tijddilatatie__. Sinds Einstein weten we dat de tijdsbeleving relatief is, en afhangt van zowel de beweging als de zwaartekracht. In ons dagelijks leven hebben we daar weinig last van, maar als je in een raket stapt die supersnel de aarde verlaat, dan verloopt de tijd voor jou langzamer dan voor iemand die op aarde blijft. Jijzelf merkt daar niks van... totdat je op aarde terugkomt en iedereen een stuk ouder blijkt dan je had gedacht.
#
# Tijddilatatie is meer dan een theorie. Experimenteel is aangetoond dat het effect echt bestaat:
#
# - Door de tijddilatatie bereiken veel meer [muonen](https://en.wikipedia.org/wiki/Muon) het aardoppervlak dan anders het geval zou zijn. Een dergelijk gedocumenteerd experiment werd in 1941 uitgevoerd door de natuurkundigen D. Hall en Bruno Rossi, op twee verschillende hoogtelocaties bij Mount Washington in het noordoosten van de Verenigde Staten (hoogteverschil bijna 2000 meter). In 1963 werd dit experiment herhaald door de Amerikanen David H. Frisch en James H. Smith die hun werk op film vastlegden.
#
# - Op aarde kan dit effect met een deeltjesversneller waargenomen worden. Elementaire deeltjes kunnen met behulp van elektrische velden gemakkelijk tot dicht bij de lichtsnelheid versneld worden. Of nou ja, gemakkelijk... een deeltjesversneller sleutel je niet zomaar op zolder in elkaar. Of jij wel?
#
# - Men heeft snelle vliegtuigen uitgerust met _zeer_ nauwkeurige atoomklokken. Na een reis rond de aarde bleken de klokken iets minder tijdsduur gemeten te hebben dan klokken die op aarde waren gebleven. Je kunt ook niks meer vertrouwen tegenwoordig. Dus, als je binnenkort met je ouders naar Australië op vakantie gaat, wel effe je horloge goed zetten hè?
#
# - GPS satellieten worden gecorrigeerd voor het effect van tijddilatatie, omdat je anders hopeloos verdwaald zou raken met je Tom Tom of [Google Maps](https://www.google.com/maps).
#
# Nog even over de grafiek die we hieronder gaan tekenen. Een X/Y grafiek laat de relatie tussen twee variabelen zien. Gewoonlijk gebruiken we de horizontale as (ook wel de X-as) voor de _onafhankelijke_ variabele en de vertikale as (ook wel de Y-as) voor de _afhankelijke_ variabele.
#
# Een voorbeeld is dat je een grafiek maakt van de temperatuur. Je meet gedurende een dag elk uur (de onafhankelijk variabele) de temperatuur (de afhankelijke variabele, want de temperatuur hangt af van hoe laat het is. 's Nachts is het bijvoorbeeld kouder dan overdag). Je krijgt dan een X/Y-grafiek waarop je kunt zien hoe de temperatuur _afhangt_ van het tijdstip.
#
# In onze grafiek hieronder is de tijd juist de _afhankelijke_ variabele, omdat we hebben gezien dat tijdsduur afhangt van beweging en zwaartekracht. Op de X-as zetten we snelheid van het ruimteschip. In dit geval hangt de tijdsduur (Y-as) dus af van de snelheid (X-as). Kun je het nog volgen?

# %%
# Tijddilatatie (dilatatie = uitrekking) is het verschijnsel dat volgens een waarnemer 
# de tijd van een andere waarnemer trager verloopt. Men onderscheidt tijddilatatie in verband 
# met beweging, en die in verband met gravitatie: gravitationele tijddilatatie.
# Bron: https://nl.wikipedia.org/wiki/Tijddilatatie
# In onze grafiek laten we de gravitationele tijddilatatie buiten beschouwing.

# We gaan een grafiek tekenen met matplotlib.

import matplotlib.pyplot as plt


# NumPy is een mooie wetenschappelijke numerieke module voor wiskundige berekeningen.

import numpy as np


# De lichtsnelheid (in meters per seconde).

c = 299792458


# Periode waar we naar kijken in seconden.
# Je kunt deze aanpassen, maar dat maakt voor de vorm van de grafiek niets uit.
# Probeer het maar!

periode = 60


# Het ruimteschip gaat van stilstand (0) tot bijna de lichtsnelheid (c).
# Zoals je weet kan een ruimteschip nooit met de lichtsnelheid reizen,
# want dan zou het oneindig zwaar worden.
# np.arange() maakt een reeks getallen uit. We stappen van 0 (stilstand)
# naar 1 (lichtsnelheid) in honderd stapjes (dat is die 0.01).
# Maar de lichtsnelheid is niet "1", dus vermenigvuldigen we steeds met c,
# de lichtsnelheid. Die reeks tussen 0.0 en 1.0 is dus een vermenigvuldigingsfactor.

t = np.arange(0.0, 1, 0.01) * c


# De formule voor tijddilatatie. En bedankt, Einstein.
# http://www.softschools.com/formulas/physics/time_dilation_formula/222/
# Hier gebeurt iets heel moois. Probeer het maar eens te volgen.
# De formule, die geloven we voor nu maar even. 
# Het resultaat, dat in de variabele s wordt gestopt, is ook weer een reeks
# met net zoveel punten als t. Met deze ene regel voeren we dus een berekening uit
# op een heleboel getallen (alles in de variabele t).
# np.sqrt() is trouwens gewoon de wortelformule. Weet je wel, np.sqrt(9) is 3.

s = periode / np.sqrt(1 - (t / c))


# Teken de grafiek.

plt.plot(t, s)

# Kies een mooie stijl voor de grafiek.
# Als je wilt zien wat er allemaal beschikbaar is:
# print (plt.style.available)

plt.style.use('seaborn-white')

# Zet in elke grafiek voortaan altijd wat wat is. Super belangrijk!!!!
# Als er niks staat kan het net zo goed konijnen per vierkante meter gras zijn.

plt.xlabel('Snelheid ruimteschip (m/sec)')
plt.ylabel(str(periode) + ' sec. in ruimteschip gezien vanaf aarde')
plt.title('Tijd-kromming in een ruimteschip')

# Teken er nog een grid (ruitjespapier) over. Lijkt me wel cool.

plt.grid(True)

plt.show()

# Probeer de grafiek uit te lezen. Zie je dat de 60 seconden in het ruimteschip
# vanaf iemand op aarde steeds langer lijken te duren naarmate het ruimteschip harder gaat?
# De X-as zegt m/sec (meters per seconde) en matplotlib heeft er rechtsonder 1e8 achter gefrommeld.
# Dat betekent dat 3.0 niet 3 meter/seconde betekent, maar 300000000 meter/seconde.
# En zie je ook dat Einstein gelijk heeft? Als de formule klopt, wordt de tijdsduur oneindig lang
# als het ruimteschip de lichtsnelheid bereikt. Dat kan niet, maar als het kon, zou de tijd stilstaan.

# %% [markdown]
# # Nu is het tijd voor een sterrenhemel
#
# Natuurlijk kun je met matplotlib ook andere dingen tekenen. Laten we eens proberen een soort sterrenhemel te tekenen.

# %%
# We tekenen uiteraard weer met onze beste nieuwe vriend, matplotlib.

import matplotlib.pyplot as plt


# En NumPy is ook weer van de partij voor de wiskundige zaken.

import numpy as np


# Hoeveel sterren wil je?
# Pas dit getal gerust aan en voer de Pythoncode opnieuw uit
# om het resultaat te zien.

aantal_sterren = 80

# Zet sterren op een willekeurige locatie.
# De functie np.random.rand() geeft ons een reeks getallen tussen 0 en 1 terug.
# 0 kan voorkomen, 1 nooit. In de wiskunde zeggen we dan, de reeks [0,1)
# Dat betekent vanaf 0 (vandaar die rechte haak) maar TOT 1 (vandaar die ronde haak).
# Zie: https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.rand.html

x = np.random.rand(aantal_sterren)
y = np.random.rand(aantal_sterren)

# Voor de kleuren hebben we net zoveel willekeurige waarden
# tussen 0 en 1 nodig als dat we sterren tekenen.

colors = np.random.rand(aantal_sterren)

# Niet elke ster is even groot. Het is gebruikelijk sterren iets groter
# te tekenen als ze helderder zijn, alhoewel ze voor je oog in het echt
# oneindig klein zijn. Hieronder maken we de sterren willekeurig in grootte
# met de bekende formule van het oppervlak van een cirkel.
# Als je radius groter maakt, krijg je knoepers van sterren!
# https://nl.wikipedia.org/wiki/Cirkel

radius = 3.0
area = np.pi * (radius * np.random.rand(aantal_sterren))**2

# We zien alleen sterren als het donker genoeg is.

plt.style.use('dark_background')

# Matplotlib gebruikt color maps. 'Wistia' is eentje die mooie
# sterrenkleurtjes tekent, maar als je los wilt gaan, kijk dan hier:
# https://matplotlib.org/examples/color/colormaps_reference.html
  
plt.set_cmap('Wistia')

# En nu tekenen we ons sterrenkaartje als "scatter plot",
# en we hoeven in dit geval geen x- en y-as te zien.
# Aan de scatter() functie van matplotlib geven we respectievelijk door:
# - De horizontale locatie van onze ster (x).
# - De vertikale locatie van onze ster (y).
# - De kleuren van onze sterren.
# - De grootte van onze sterren.
# - Een transparantie-waarde. Dat noemen we ook wel alpha.

plt.axis('off')
plt.axis([0, 1, 0, 1])
plt.scatter(x, y, c=colors, s=area, alpha=.9)
plt.show()

# Elke keer als je deze code uitvoert, krijg je een nieuwe willekeurige sterrenhemel.

# %%
# En als laatste voor nu, tekst met Matplotlib.

import matplotlib.pyplot as plt

# We gebruiken maar weer eens een andere stijl.
# ggplot laat de afbeelding mooi zien met een grijze achtergrond.

plt.style.use('ggplot')

# xlim en ylim zijn handige functies om zelf te bepalen
# welk gedeelte van je grafiek je wilt zien.
# Daarmee duw je de x-as en y-as in de juiste posities.

plt.xlim([-3, 10])
plt.ylim([-3, 10])

# plt.text() wil graag de volgende 4 dingen van je horen:
# - De x-positie van de tekst.
# - De y-positie van de tekst.
# - De tekst zelf.
# - De grootte van de letters (dat noemen we fontsize).

plt.text(-1.5, -1.5, 'J.W.G.', fontsize=60)
plt.text(0, 6, 'sterrenkunde', fontsize=30)
plt.text(2, 3, 'ruimtevaart', fontsize=20)

plt.show()

# %%
# Uitdaging! Om alles wat je in deze aflevering hebt geleerd te combineren
# kun je proberen de datum en de tijd van vandaag met matplotlib weer
# te geven. Als je avontuurlijk bent, gebruik dan verschillende kleuren!

# Natuurlijk begint je programma met deze regel.

import matplotlib.pyplot as plt

# ... hier komt jouw code ...
# ... hier komt jouw code ...
# ... hier komt jouw code ...
# ... hier komt jouw code ...
# ... hier komt jouw code ...

print("Succes!")
